# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop('deck',axis=1, inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
x=df
df1=x
df1.dropna(inplace=True)

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.scatterplot(x='age',y='fare',data=df1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(x='age',y='fare',data=df1,hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
sns.histplot(df1,x='fare',hue='pclass',bins=10)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(df1,x='fare',hue='pclass',bins=10,kde=True)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.displot(df1['fare'],aspect=3)

# %%
sns.displot(df1,x='age',hue='sex',aspect=3)

# %%
sns.displot(df1,x='age',hue='sex',col='pclass',aspect=1)

# %%
sns.displot(df1,x='age',hue='sex',col='pclass',aspect=1,kde=True)

# %%
sns.displot(df1,x='fare',hue='sex',col='pclass')

# %%
sns.boxplot(x='sex',y='age',data=df1)  #barplot is for categorical values
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(y='sex',x='age',data=df1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.barplot(x='sex',y='age',hue='embarked',data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex',y='age',hue='embarked',data=df1,ci=None)    #ci is to remove the lines on the graph
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex',y='age',hue='pclass',data=df1,ci=None)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.countplot(x='pclass',data=df1)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(x='pclass',hue='sex',data=df1)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(x='pclass',hue='sex',data=df1,dodge=False)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.displot(x='age',hue='survived',data=df1)

# %%
sns.lineplot(x='age',y='fare',data=df1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
#other examples

# %%
sns.displot(data=df1, kind="ecdf", x="age",  hue="pclass", rug=True)
